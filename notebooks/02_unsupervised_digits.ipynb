# %% [markdown]
# # Kiln Track B — Unsupervised (Digits PCA)

# %%
# !pip install -q -e .
from kiln.eval.harness import run_unsupervised_track
results = run_unsupervised_track(seed=42)
for r in results:
    print(r.model, r.metrics.primary_value)
